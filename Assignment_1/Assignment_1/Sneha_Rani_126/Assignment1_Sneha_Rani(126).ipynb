# %% [markdown]
# SNEHA RANI (12601182025)
#
#
# ---
# ML AND GENAI INTERNSHIP💻 Assignment-1

# %% [markdown]
# # Ques 1. Find Area of **Rectangle**

# %%
length = int(input("Enter length = "))
breadth = int(input("Enter breadth ="))

area = length * breadth

print("Area of Rectangle =", area)
# Out:
# Enter length = 2
# Enter breadth =4
# Area of Rectangle = 8

# %% [markdown]
# # Ques 2. Find Simple Interest

# %%
p = float(input("Enter Principal Amount= "))
r = float(input("Enter Rate of Interest= "))
t = float(input("Enter Time (in years)= "))

simple_interest = (p * r * t) / 100

print("Simple Interest =", simple_interest)
# Out:
# Enter Principal Amount= 2000
# Enter Rate of Interest= 4
# Enter Time (in years)= 3
# Simple Interest = 240.0

# %% [markdown]
# # Ques 3. Convert Celsius to Fahrenheit

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter temperature in Celsius: 25
# Temperature in Fahrenheit = 77.0

# %% [markdown]
# # Ques 4. Calculate Average of 3 Numbers

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

average = (num1 + num2 + num3) / 3

print("Average =", average)
# Out:
# Enter first number: 90
# Enter second number: 80
# Enter third number: 70
# Average = 80.0

# %% [markdown]
# # Ques 5. Find Square and Cube of a Number

# %%
num = float(input("Enter a number: "))

square = num ** 2
cube = num ** 3

print("Square =", square)
print("Cube =", cube)
# Out:
# Enter a number: 2
# Square = 4.0
# Cube = 8.0

# %% [markdown]
# # Ques 6. Swap Two Numbers Without Using Third Variable

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a = a + b
b = a - b
a = a - b

print("After Swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 3
# Enter second number: 2
# After Swapping:
# a = 2
# b = 3

# %% [markdown]
# # Ques 7. Create a Student Report Program

# %%
# Student Report Program

# Input student details
name = input("Enter Student Name: ")
roll_no = input("Enter Roll Number: ")

# Input marks of 3 subjects
mark1 = float(input("Enter marks of Subject 1: "))
mark2 = float(input("Enter marks of Subject 2: "))
mark3 = float(input("Enter marks of Subject 3: "))

# Calculate total marks
total = mark1 + mark2 + mark3

# Calculate percentage
percentage = (total / 300) * 100

# Display report
print("\n----- Student Report -----\n") #\n for next line
print("Name       :", name)
print("Roll No    :", roll_no)
print("Marks      :", mark1, mark2, mark3)
print("Total      :", total)
print("Percentage :", percentage, "%")
# Out:
# Enter Student Name: Sneha Rani
# Enter Roll Number: 12601182025
# Enter marks of Subject 1: 93
# Enter marks of Subject 2: 90
# Enter marks of Subject 3: 97
#
# ----- Student Report -----
#
# Name       : Sneha Rani
# Roll No    : 12601182025
# Marks      : 93.0 90.0 97.0
# Total      : 280.0
# Percentage : 93.33333333333333 %
